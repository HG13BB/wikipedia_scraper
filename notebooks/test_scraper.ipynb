# %%
#!pip uninstall wiki_file_type_scraper
#!pip install git+https://github.com/HG13BB/wikipedia_scraper.git

# %%
import wiki_file_type_scraper.wiki_file_type_scraper as wft

# %%
wft.final_output()
# Out:
#                file_category  \
# 0     Archive and compressed
# 1     Archive and compressed
# 2     Archive and compressed
# 3     Archive and compressed
# 4     Archive and compressed
# ...                      ...
# 858       Biomedical imaging
# 1280                   Video
# 1280                   Video
# 1280                   Video
# 1355         Video game data
#
#                                               file_info  \
# 0     .?mn - is a custom file made by Team Gasterele...
# 1     .?Q? – files that are compressed, often by the...
# 2                            7z – 7-Zip compressed file
# 3              A - An external file extension for C/C++
# 4                                 AAPKG – ArchestrA IDE
# ...                                                 ...
# 858   Medical Imaging NetCDF (MINC) format, previous...
# 1280                           MPEG (.mpeg, .mpg, .mpe)
# 1280                           MPEG (.mpeg, .mpg, .mpe)
# 1280                           MPEG (.mpeg, .mpg, .mpe)
# 1355  sometimes used for general data contained with...
#
#                                              wikilink file_ext
# 0                                                None    .?mn
# 1                                                None     .?Q?
# 2     https://en.wikipedia.org//wiki/7z_(file_format)   7z – 7
# 3                                                None       A
# 4                                                None    AAPKG
# ...                                               ...      ...
# 858                                              None      mnc
# 1280              https://en.wikipedia.org//wiki/MPEG     mpeg
# 1280              https://en.wikipedia.org//wiki/MPEG      mpg
# 1280              https://en.wikipedia.org//wiki/MPEG      mpe
# 1355                                             None      PK3
#
# [1591 rows x 4 columns]
